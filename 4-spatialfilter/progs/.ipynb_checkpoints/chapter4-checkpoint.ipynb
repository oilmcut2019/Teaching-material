# %% [markdown]
# # Chapter 4

# %% [markdown]
# #### Spatial Filters

# %%
import cv2
import numpy as np
import scipy.ndimage
import matplotlib.pyplot as plt

# Opening the image using cv2.
a = cv2.imread('../Figures/ultrasound_muscle.png')
# Converting the image to grayscale.
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)

# Initializing the filter of size 5 by 5.
# The filter is divided by 25 for normalization.
k = np.ones((5,5))/25
# performing convolution
b = scipy.ndimage.filters.convolve(a, k)
# Writing b to a file.
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Median Filter

# %%
import cv2
import scipy.ndimage
import matplotlib.pyplot as plt

# Opening the image and converting it to grayscale.
a = cv2.imread('../Figures/ct_saltandpepper.png')
# Converting the image to grayscale.
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing the median filter.
b = scipy.ndimage.filters.median_filter(a, size=5)
# Saving b as median_output.png in Figures folder
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Max Filter

# %%
import scipy.misc
import scipy.ndimage
from scipy.misc.pilutil import Image
import matplotlib.pyplot as plt

# opening the image and converting it to grayscale
a = Image.open('../Figures/wave.png').convert('L')
# performing maximum filter
b = scipy.ndimage.filters.maximum_filter(a, size=5)
# b is converted from an ndarray to an image
b = scipy.misc.toimage(b)
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Min Filter

# %%
import cv2
import scipy.ndimage
import matplotlib.pyplot as plt

# opening the image and converting it to grayscale
a = cv2.imread('../Figures/wave.png')

# performing minimum filter
b = scipy.ndimage.filters.minimum_filter(a, size=5)
# saving b as mino.png
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Sobel Filter

# %%
import cv2
from scipy import ndimage
import matplotlib.pyplot as plt

# Opening the image.
a = cv2.imread('../Figures/cir.png')
# Converting a to grayscale .
a = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
# Performing Sobel filter.
b = ndimage.sobel(a)
# Saving b.
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Canny Filter

# %%
import cv2
import matplotlib.pyplot as plt

# Opening the image.
a = cv2.imread('../Figures/maps1.png')
# Performing Canny edge filter.
b = cv2.Canny(a, 100, 200)
# Saving b.
plt.imshow(a)
plt.show()

# %% [markdown]
# #### Laplacian Filter

# %%
import cv2
import scipy.ndimage
import matplotlib.pyplot as plt

# Opening the image.
a = cv2.imread('../Figures/imagefor_laplacian.png')
# Performing Laplacian filter.
b = scipy.ndimage.filters.laplace(a,mode='reflect')
plt.imshow(a)
plt.show()

# %% [markdown]
# # Laplacian of Gaussian Filter

# %%
import cv2
import scipy.ndimage
import matplotlib.pyplot as plt

# Opening the image.
a = cv2.imread('../Figures/vhuman_t1.png')
# Performing Laplacian of Gaussian.
b = scipy.ndimage.filters.gaussian_laplace(a, sigma=1, mode='reflect')
plt.imshow(a) 
plt.show()

# %% [markdown]
# # Frangi Filter

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
from PIL import Image
from skimage.filters import frangi

img = cv2.imread('../Figures/angiogram1.png')
img1 = np.asarray(img)
img2 = frangi(img1, black_ridges=True)
img3 = 255*(img2-np.min(img2))/(np.max(img2)-np.min(img2))
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-229ccec712c4> in <module>
#       5 import numpy as np
#       6 from PIL import Image
# ----> 7 from skimage.filters import frangi
#       8
#       9 img = cv2.imread('../Figures/angiogram1.png')
#
# ~/environment/dip/lib/python3.6/site-packages/skimage/filters/__init__.py in <module>
#       2 from ._gaussian import (gaussian, _guess_spatial_dimensions,
#       3                         difference_of_gaussians)
# ----> 4 from .edges import (sobel, sobel_h, sobel_v,
#       5                     scharr, scharr_h, scharr_v,
#       6                     prewitt, prewitt_h, prewitt_v,
#
# ~/environment/dip/lib/python3.6/site-packages/skimage/filters/edges.py in <module>
#      16 from scipy.ndimage import convolve, binary_erosion
#      17
# ---> 18 from ..restoration.uft import laplacian
#      19
#      20 # n-dimensional filter weights
#
# ~/environment/dip/lib/python3.6/site-packages/skimage/restoration/__init__.py in <module>
#       3 """
#       4
# ----> 5 from .deconvolution import wiener, unsupervised_wiener, richardson_lucy
#       6 from .unwrap import unwrap_phase
#       7 from ._denoise import (denoise_tv_chambolle, denoise_tv_bregman,
#
# ~/environment/dip/lib/python3.6/site-packages/skimage/restoration/deconvolution.py in <module>
#       4 import numpy as np
#       5 import numpy.random as npr
# ----> 6 from scipy.signal import convolve
#       7
#       8 from . import uft
#
# ~/environment/dip/lib/python3.6/site-packages/scipy/signal/__init__.py in <module>
#     303
#     304 from .bsplines import *
# --> 305 from .filter_design import *
#     306 from .fir_filter_design import *
#     307 from .ltisys import *
#
# ~/environment/dip/lib/python3.6/site-packages/scipy/signal/filter_design.py in <module>
#      17 from scipy import special, optimize
#      18 from scipy.special import comb, factorial
# ---> 19 from scipy._lib._numpy_compat import polyvalfromroots
#      20
#      21
#
# ~/environment/dip/lib/python3.6/site-packages/scipy/_lib/_numpy_compat.py in <module>
#       8
#       9 import numpy as np
# ---> 10 from numpy.testing.nosetester import import_nose
#      11
#      12 from scipy._lib._version import NumpyVersion
#
# ModuleNotFoundError: No module named 'numpy.testing.nosetester'

# %%
pip list
# Out:
# Package             Version
# ------------------- ---------
# argon2-cffi         20.1.0
# async-generator     1.10
# attrs               20.2.0
# backcall            0.2.0
# bleach              3.2.1
# certifi             2020.6.20
# cffi                1.14.3
# cycler              0.10.0
# decorator           4.4.2
# defusedxml          0.6.0
# entrypoints         0.3
# imageio             2.9.0
# importlib-metadata  2.0.0
# ipykernel           5.3.4
# ipython             7.16.1
# ipython-genutils    0.2.0
# ipywidgets          7.5.1
# jedi                0.17.2
# Jinja2              2.11.2
# jsonschema          3.2.0
# jupyter             1.0.0
# jupyter-client      6.1.7
# jupyter-console     6.2.0
# jupyter-core        4.6.3
# jupyterlab-pygments 0.1.2
# kiwisolver          1.3.1
# MarkupSafe          1.1.1
# matplotlib          3.3.2
# mistune             0.8.4
# nbclient            0.5.1
# nbconvert           6.0.7
# nbformat            5.0.8
# nest-asyncio        1.4.2
# networkx            2.5
# notebook            6.1.4
# numpy               1.19.3
# opencv-python       4.2.0.32
# packaging           20.4
# pandocfilters       1.4.3
# parso               0.7.1
# pexpect             4.8.0
# pickleshare         0.7.5
# Pillow              8.0.1
# pip                 20.2.4
# pkg-resources       0.0.0
# prometheus-client   0.8.0
# prompt-toolkit      3.0.8
# ptyprocess          0.6.0
# pycparser           2.20
# Pygments            2.7.2
# pyparsing           2.4.7
# pyrsistent          0.17.3
# python-dateutil     2.8.1
# PyWavelets          1.1.1
# pyzmq               19.0.2
# qtconsole           4.7.7
# QtPy                1.9.0
# scikit-image        0.17.2
# scipy               0.19.1
# Send2Trash          1.5.0
# setuptools          39.0.1
# six                 1.15.0
# terminado           0.9.1
# testpath            0.4.4
# tifffile            2020.9.3
# tornado             6.1
# traitlets           4.3.3
# wcwidth             0.2.5
# webencodings        0.5.1
# widgetsnbextension  3.5.1
# zipp                3.4.0
# Note: you may need to restart the kernel to use updated packages.
